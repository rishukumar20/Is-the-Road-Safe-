# %%
import tensorflow as tf #platform used for machine learning applications
import pandas as pd #for data analysis and manipulation
import numpy as np # for accessing and manipulation of n dimensional array

# %%
import keras #open source neural network library

# %%
import glob #return the file paths

# %%
train_files=glob.glob('C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask/*')

# %%
print(train_files)
# Out:
# ['C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,000.jpg', 'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,001.jpg', 'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,002.jpg', 'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,003.jpg', 'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,004.jpg', 'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,005.jpg', 'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,006.jpg', 'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,007.jpg', 'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,008.jpg', 'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,009.jpg', 'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/wi
# ...

# %%
train_files #printing the data from the dataset presint in this location
# Out:
# ['C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,000.jpg',
#  'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,001.jpg',
#  'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,002.jpg',
#  'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,003.jpg',
#  'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,004.jpg',
#  'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,005.jpg',
#  'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,006.jpg',
#  'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,007.jpg',
#  'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,008.jpg',
#  'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,009.jpg',
# ...

# %%
train_files[0] # accessing any particular element from array using numpy library
# Out:
# 'C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\\image1,000.jpg'

# %%
print(train_files[0])
# Out:
# C:/Users/DIBYAJYOTI HALOI/OneDrive/Desktop/club project/archive/with_mask\image1,000.jpg

# %%
import matplotlib.pyplot as plt #helps in visualising data using different graphs
from PIL import Image #helps in loading and manipulation of images

# %%
# !pip install pillow

# %%
img1=Image.open(train_files[0]) #defining 1st data from dataset

# %%
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=104x148 at 0x22C6D62F040>

# %%
print(img1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=104x148 at 0x22C6D62F040>

# %%
img1_array=np.array(img1) #numpy helps in converting img1 to 3-dimensional array

# %%
img1_array
# Out:
# array([[[ 27,  27,  35],
#         [ 25,  25,  35],
#         [ 22,  25,  34],
#         ...,
#         [ 48,  47,  52],
#         [ 52,  52,  54],
#         [ 60,  60,  62]],
#
#        [[ 30,  30,  38],
#         [ 30,  30,  38],
#         [ 24,  27,  36],
#         ...,
#         [ 55,  54,  59],
#         [ 53,  53,  55],
#         [ 58,  58,  60]],
#
#        [[ 32,  32,  40],
#         [ 34,  34,  42],
#         [ 30,  30,  38],
#         ...,
#         [ 59,  58,  63],
#         [ 56,  56,  58],
#         [ 58,  58,  60]],
#
#        ...,
#
#        [[173, 193, 202],
#         [117, 137, 148],
#         [ 69,  88, 102],
#         ...,
#         [ 30,  24,  24],
#         [ 15,  13,  14],
#         [ 13,  13,  13]],
#
#        [[165, 185, 194],
#         [117, 137, 148],
#         [ 70,  89, 103],
#         ...,
#         [ 23,  19,  20],
#         [ 19,  17,  18],
#         [ 12,  12,  12]],
#
#        [[159, 179, 188],
#         [117, 137, 148],
#         [ 59,  79,  90],
# ...

# %%
print(img1_array)
# Out:
# [[[ 27  27  35]
#   [ 25  25  35]
#   [ 22  25  34]
#   ...
#   [ 48  47  52]
#   [ 52  52  54]
#   [ 60  60  62]]
#
#  [[ 30  30  38]
#   [ 30  30  38]
#   [ 24  27  36]
#   ...
#   [ 55  54  59]
#   [ 53  53  55]
#   [ 58  58  60]]
#
#  [[ 32  32  40]
#   [ 34  34  42]
#   [ 30  30  38]
#   ...
#   [ 59  58  63]
#   [ 56  56  58]
#   [ 58  58  60]]
#
#  ...
#
#  [[173 193 202]
#   [117 137 148]
#   [ 69  88 102]
#   ...
#   [ 30  24  24]
#   [ 15  13  14]
#   [ 13  13  13]]
#
#  [[165 185 194]
#   [117 137 148]
#   [ 70  89 103]
#   ...
#   [ 23  19  20]
#   [ 19  17  18]
#   [ 12  12  12]]
#
#  [[159 179 188]
#   [117 137 148]
#   [ 59  79  90]
#   ...
#   [ 18  14  15]
#   [ 20  18  19]
#   [  7   7   7]]]

# %%
print(img1_array.shape) #gives order layers,rows and columns of the defined dataset
# Out:
# (148, 104, 3)
